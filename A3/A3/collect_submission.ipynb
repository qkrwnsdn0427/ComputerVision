# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a ITE4052 folder and put all the files under A3 folder, then 'ITE4052/A3'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'ITE4052/A3'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'ITE4052/A3'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['collect_submission.ipynb', 'makepdf.py', 'ite4052', 'linear_classifier.py의 사본', 'two_layer_net.py의 사본', '__pycache__', 'linear_classifier.py', 'svm_best_model.pt', 'softmax_best_model.pt', 'linear_classifier.ipynb', 'hand_drawn_weights.jpeg', 'a3_inline_submission.pdf', 'challenge_problem.ipynb', 'two_layer_net.py', 'collectSubmission.sh', 'nn_best_model.pt', 'sukminyun_12345678_A3.zip', 'NAME_ID_A3.pdf', 'two_layer_net.ipynb']

# %% [markdown]
# ## Submit Your Work - Zip + Generate PDF
# 1. After completing both notebooks for this assignment, run the following cell to create a `.zip` file for you to download and turn in. **Please MANUALLY SAVE every `*.ipynb` and `*.py` files before executing the following cell:**
#
# 2. Convert all notebooks into a single PDF file called `NAME_ID_A3.pdf`.
# If your submission for this step was successful, you should see the following display message:
# `### Done! Please submit NAME_ID_A3.pdf to LMS. ###`. **Please MANUALLY change your `NAME_ID_A3.pdf` to your unique filename (e.g., `sukminyun_12345678_A3.pdf`)**
#
# Make sure to download the zip and pdf file locally to your computer, then submit to LMS. Congrats on succesfully completing the assignment!

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

# %%
from ite4052.submit import make_a3_submission

# TODO: Replace these with your actual uniquename and umid
uniquename = 'sukminyun'
hyid = 12345678
make_a3_submission(GOOGLE_DRIVE_PATH, uniquename, hyid)
# Out:
# Writing zip file to:  drive/My Drive/ITE4052/A3/sukminyun_12345678_A3.zip

# %%
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic
# !pip install PyPDF2
# %cd $GOOGLE_DRIVE_PATH
# !bash collectSubmission.sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# texlive-fonts-recommended is already the newest version (2021.20220204-1).
# texlive-plain-generic is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# /content/drive/My Drive/ITE4052/A3
# ### Creating PDFs ###
# Created PDF linear_classifier.ipynb.
# Created PDF two_layer_net.ipynb.
# ### Done! Please submit NAME_ID_A3.pdf to LMS. ###
