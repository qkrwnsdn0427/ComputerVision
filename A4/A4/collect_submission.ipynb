# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a ITE4052 folder and put all the files under A4 folder, then 'ITE4052/A4'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'ITE4052/A4'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'ITE4052/A4'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))

# %% [markdown]
# ## Submit Your Work - Zip + Generate PDF
# 1. After completing both notebooks for this assignment(`fully_connected_networks.ipynb` and this notebook, `convolutional_networks.ipynb`), run the following cell to create a `.zip` file for you to download and turn in. **Please MANUALLY SAVE every `*.ipynb` and `*.py` files before executing the following cell:**
#
# 2. Convert all notebooks into a single PDF file called `NAME_ID_A4.pdf`.
# If your submission for this step was successful, you should see the following display message:
# `### Done! Please submit NAME_ID_A4.pdf to LMS. ###`. **Please MANUALLY change your `NAME_ID_A4.pdf` to your unique filename (e.g., `sukminyun_12345678_A4.pdf`)**
#
# Make sure to download the zip and pdf file locally to your computer, then submit to LMS. Congrats on succesfully completing the assignment!

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

# %%
from ite4052.submit import make_a4_submission

# TODO: Replace these with your actual uniquename and umid
uniquename = 'sukminyun'
hyid = 12345678
make_a4_submission(GOOGLE_DRIVE_PATH, uniquename, hyid)

# %%
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic
# !pip install PyPDF2
# %cd $GOOGLE_DRIVE_PATH
# !bash collectSubmission.sh
