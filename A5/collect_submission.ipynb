# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a ITE4052 folder and put all the files under A5 folder, then 'ITE4052/A5'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'ITE4052/A5'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))

# %% [markdown]
# ## Submit Your Work - Zip (Only)
#
# After completing both notebooks for this assignment(`variational_autoencoders.ipynb` and this notebook, `generative_adversarial_networks.ipynb`), run the following cell to create a `.zip` file for you to download and turn in. **Please MANUALLY SAVE every `*.ipynb` and `*.py` files before executing the following cell**
#
# Make sure to download the zip file locally to your computer, then submit to LMS. Congrats on succesfully completing the assignment!

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

# %%
from ite4052.submit import make_a5_submission

# TODO: Replace these with your actual uniquename and umid
uniquename = 'sukminyun'
hyid = 12345678
make_a5_submission(GOOGLE_DRIVE_PATH, uniquename, hyid)
